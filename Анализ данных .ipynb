# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Mi'

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Mi\\Downloads\\c (1).csv')
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# Вычислите среднее по продажам в Японии (миллионы копий) – переменная JP_Sales.

# %%
mean_JP = df['JP_Sales'].mean()
print(round(mean_JP, 2))
# Out:
# 0.08

# %% [markdown]
# Вычислите минимальное значение по продажам в Японии (миллионы копий) – переменная JP_Sales.

# %%
min_JP = df['JP_Sales'].min()
min_JP
# Out:
# 0.0

# %% [markdown]
# Возможно, в датасете есть пропущенные значения. Необходимо их убрать

# %%
na = df[df['JP_Sales'].isna()].sum()
na
# Out:
# Name               0.0
# Platform           0.0
# Year_of_Release    0.0
# Genre              0.0
# Publisher          0.0
# NA_Sales           0.0
# EU_Sales           0.0
# JP_Sales           0.0
# Other_Sales        0.0
# Global_Sales       0.0
# Critic_Score       0.0
# Critic_Count       0.0
# User_Score         0.0
# User_Count         0.0
# Developer          0.0
# Rating             0.0
# dtype: float64

# %% [markdown]
# В нашем датасете нет пропущенных значений, следовательно, 0 - это минимальное значение

# %% [markdown]
# Вычислите максимальное значение по продажам в Японии (миллионы копий) – переменная JP_Sales.

# %%
maximum = df['JP_Sales'].max()
maximum
# Out:
# 10.22

# %% [markdown]
# Определите наиболее часто встречающуюся платформу для запуска игры.

# %% [markdown]
# Для того, чтобы рассчитать частоты в таблице, воспользуемся функией value_counts и применим ее к столбцу Platform

# %%
number = df['Platform'].value_counts()
number
# Out:
# PS2     2161
# DS      2152
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      432
# PS4      393
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %% [markdown]
# PS2 - наиболее часто встречающаяся платформа

# %% [markdown]
# Добавьте в таблицу новый признак Dev_Coded, который будет представлять собой закодированное название разработчика игры (переменная Developer). Кодировку проведите следующим образом: если разработчик – это Ubisoft, то код равен 1, а если любой другой, то код равен 0.
#
# Выведите среднее по признаку Dev_Coded, округлённое до сотых.

# %% [markdown]
# #### ЕСЛИ ДОБАВЛЯЕМ НОВЫЕ ПЕРЕМЕННЫЕ, ЛУЧШЕ ПЕРЕЗАПИСАТЬ МАССИВ ДАННЫХ

# %%
df1 = df

# %%
df1['Dev_Coded'] = df1['Developer'].apply(lambda x: 1 if x == 'Ubisoft' else 0)
df1.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %% [markdown]
# Выведите среднее по признаку Dev_Coded, округлённое до сотых.

# %%
mean = df1['Dev_Coded'].mean()
print(round(mean, 2))
# Out:
# 0.01

# %% [markdown]
# Выведите медиану продаж в Северной Америке (миллионы копий) – переменная NA_Sales – для игр, выпущенных (published) компанией Nintendo. Ответ округлите до сотых.

# %%
median_NA = df[df['Publisher'] == 'Nintendo']
median = median_NA['NA_Sales'].median()
print(round(median, 2))
# Out:
# 0.36

# %% [markdown]
# Определите количество пропущенных значений для переменной User_Count. Выпишите найденное количество пропущенных значений.

# %%
na = df[df['User_Count'].isna()]
na
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                             Tetris       GB           1989.0        Puzzle
# 9                          Duck Hunt      NES           1984.0       Shooter
# 10                        Nintendogs       DS           2005.0    Simulation
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# Смотрим на размерность внизу таблицы (9129 rows × 17 columns) - количество пропущенных значений = 9129

# %% [markdown]
# Определите количество пропущенных значений признака User_Count. Замените пропущенные значения этого признака на среднее значение по этому признаку и сохраните полученный признак без пропущенных значений в отдельную переменную, не включаемую в исходную таблицу. Выпишите количество значений этой переменной, равных её медиане.

# %%
mean_UC = df['User_Count'].mean()
mean_UC
# Out:
# 162.22990777338603

# %% [markdown]
# Для того, чтобы заполнить пропущенные значения, воспользуемся функией fillna, где в качестве аргумента передаем значение, которым хотим заполнить пропущенные

# %%
df['New'] = df['User_Count'].fillna(mean_UC)
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %%
med_UC = df['User_Count'].median()
med_UC
# Out:
# 24.0

# %%
df[df['User_Count'] == med_UC]
# Out:
#                              Name Platform  Year_of_Release       Genre  \
# 68                   Just Dance 2      Wii           2010.0        Misc
# 812              The Sims 2: Pets       DS           2006.0  Simulation
# 932                       Shrek 2      PS2           2004.0    Platform
# 1002   The Urbz: Sims in the City      PS2           2004.0  Simulation
# 1094          Fight Night Round 3      PS3           2006.0    Fighting
# ...                           ...      ...              ...         ...
# 14896      The Sims 2: Bon Voyage       PC           2007.0  Simulation
# 14923  Air Conflicts: Secret Wars       PC           2011.0  Simulation
# 15769               Peggle Nights       PC           2008.0      Puzzle
# 16080            Imperium Romanum       PC           2008.0    Strategy
# 16313              Rail Simulator       PC           2007.0  Simulation
#
#                Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# Смотрим на размерность внизу таблицы (83 rows × 18 columns) - 83 значения

# %% [markdown]
# Постройте гистограмму переменной User_Count. Выберите верное утверждение.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Для того, чтобы построить графики, необходимо задать максимальное значение по оси Y. (Для этого проще отсортировать данные в Excel, потому что в питоне нихера не получается)

# %%
max_US = 9.7
max_UC = 10665

# %%
plt.hist(df['User_Count'], 10)
# Out:
# (array([7.327e+03, 1.590e+02, 5.200e+01, 2.500e+01, 9.000e+00, 6.000e+00,
#         3.000e+00, 2.000e+00, 3.000e+00, 4.000e+00]),
#  array([4.0000e+00, 1.0701e+03, 2.1362e+03, 3.2023e+03, 4.2684e+03,
#         5.3345e+03, 6.4006e+03, 7.4667e+03, 8.5328e+03, 9.5989e+03,
#         1.0665e+04]),
#  <BarContainer object of 10 artists>)

# %%
df1 = df.dropna(subset = ['User_Score'])
df1[df1['User_Score'] == 'tbd'] = 0
# Out:
# C:\Users\Mi\AppData\Local\Temp\ipykernel_6868\2509839376.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[df1['User_Score'] == 'tbd'] = 0

# %%
df1['User_Score'].astype(float)
# Out:
# 0        8.0
# 2        8.3
# 3        8.0
# 6        8.5
# 7        6.6
#         ...
# 16702    0.0
# 16706    7.2
# 16708    0.0
# 16709    5.8
# 16710    0.0
# Name: User_Score, Length: 10015, dtype: float64

# %%
plt.hist(df1['User_Score'].astype(float), 10)
# Out:
# (array([2438.,   36.,   96.,  188.,  315.,  665., 1047., 2069., 2518.,
#          643.]),
#  array([0.  , 0.97, 1.94, 2.91, 3.88, 4.85, 5.82, 6.79, 7.76, 8.73, 9.7 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Для того, чтобы построить столбачтую диаграмму для категориальной переменной, необходимо посчитать значения каждой категории

# %%
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)

# %%
for i in df['Genre']:
    count('Sports')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6868\3784682890.py in <module>
#       1 for i in df['Genre']:
# ----> 2     count('Sports')
#
# NameError: name 'count' is not defined

# %%
df['Genre'].count('Sports')
# Out:
# C:\Users\Mi\AppData\Local\Temp\ipykernel_6868\772252371.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. ser.count(level=1) should use ser.groupby(level=1).count().
#   df['Genre'].count('Sports')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6868\772252371.py in <module>
# ----> 1 df['Genre'].count('Sports')
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in count(self, level)
#    1974             )
#    1975             if not isinstance(self.index, MultiIndex):
# -> 1976                 raise ValueError("Series.count level is only valid with a MultiIndex")
#    1977
#    1978         index = self.index
#
# ValueError: Series.count level is only valid with a MultiIndex

# %%
df[df['Genre'] == 'Platform']
# Out:
#                                                    Name Platform  \
# 1                                     Super Mario Bros.      NES
# 6                                 New Super Mario Bros.       DS
# 8                             New Super Mario Bros. Wii      Wii
# 18                                    Super Mario World     SNES
# 21                                     Super Mario Land       GB
# ...                                                 ...      ...
# 16358                                    Strider (2014)      PS3
# 16360                                Goku Makaimura Kai      PSP
# 16605  The Land Before Time: Into the Mysterious Beyond      GBA
# 16712                Woody Woodpecker in Crazy Castle 5      GBA
# 16717                                  Spirits & Spells      GBA
#
#        Year_of_Release     Genre     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 1               1985.0  Platform      Nintendo     29.08      3.58      6.81
# ...

# %%
for i in df['Genre'].unique():
    print(df[df['Genre'] == i].count()[0])
# Out:
# 2348
# 888
# 1249
# 1500
# 580
# 1750
# 1323
# 874
# 3370
# 849
# 1303
# 683
# 0

# %%
# Out:
# 0

# %%
df.corr()
# Out:
#                  Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Year_of_Release         1.000000 -0.092562  0.003842 -0.168386     0.037700
# NA_Sales               -0.092562  1.000000  0.765336  0.449598     0.638654
# EU_Sales                0.003842  0.765336  1.000000  0.435068     0.722796
# JP_Sales               -0.168386  0.449598  0.435068  1.000000     0.291096
# Other_Sales             0.037700  0.638654  0.722796  0.291096     1.000000
# Global_Sales           -0.076433  0.941010  0.901239  0.612300     0.749242
# Critic_Score            0.011411  0.240755  0.220752  0.152593     0.198554
# Critic_Count            0.223407  0.295413  0.277533  0.180219     0.251639
# User_Count              0.175339  0.246429  0.283360  0.075638     0.238982
# Dev_Coded               0.045936  0.015531  0.013050 -0.026394     0.010138
# New                     0.086491  0.188975  0.249668  0.045211     0.222953
#
# ...

# %% [markdown]
# Выведите корреляционную матрицу для числовых переменных (новый признак Dev_Coded, созданный в 24-м вопросе, не учитывайте). Найдите переменную, которая имеет наименьшую по модулю корреляцию с переменной JP_Sales. В ответ выпишите модуль найденного значения корреляции. Ответ округлите до сотых.

# %%
df3 = df.corr()
df3.head()
# Out:
#                  Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Year_of_Release         1.000000 -0.092562  0.003842 -0.168386     0.037700
# NA_Sales               -0.092562  1.000000  0.765336  0.449598     0.638654
# EU_Sales                0.003842  0.765336  1.000000  0.435068     0.722796
# JP_Sales               -0.168386  0.449598  0.435068  1.000000     0.291096
# Other_Sales             0.037700  0.638654  0.722796  0.291096     1.000000
#
#                  Global_Sales  Critic_Score  Critic_Count  User_Count  \
# Year_of_Release     -0.076433      0.011411      0.223407    0.175339
# NA_Sales             0.941010      0.240755      0.295413    0.246429
# EU_Sales             0.901239      0.220752      0.277533    0.283360
# JP_Sales             0.612300      0.152593      0.180219    0.075638
# Other_Sales          0.749242      0.198554      0.251639    0.238982
#
#                  Dev_Coded       New
# Year_of_Release   0.045936  0.086491
# ...

# %%
df3['JP_Sales']
# Out:
# Year_of_Release   -0.168386
# NA_Sales           0.449598
# EU_Sales           0.435068
# JP_Sales           1.000000
# Other_Sales        0.291096
# Global_Sales       0.612300
# Critic_Score       0.152593
# Critic_Count       0.180219
# User_Count         0.075638
# Dev_Coded         -0.026394
# New                0.045211
# Name: JP_Sales, dtype: float64

# %%
df4 = df3['JP_Sales'].apply(lambda x: abs(x))

# %%
df4
# Out:
# Year_of_Release    0.168386
# NA_Sales           0.449598
# EU_Sales           0.435068
# JP_Sales           1.000000
# Other_Sales        0.291096
# Global_Sales       0.612300
# Critic_Score       0.152593
# Critic_Count       0.180219
# User_Count         0.075638
# Dev_Coded          0.026394
# New                0.045211
# Name: JP_Sales, dtype: float64

# %%
print(round(min(df4), 2))
# Out:
# 0.03

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %%
h = 3.743046343
print(round(h,2))
# Out:
# 3.74
